# %%
import pandas as pd

# %%
"""  
df.dtypes    -- Attribute
df.columns  -- Attribute
df.describe()

Column Selection
Row Selection

Row and Column Section

Handling JSON DATA


"""
print()

# %%
df = pd.read_csv("./DataSets/Advertising.csv")

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df2 = pd.read_csv("./DataSets/Advertising.csv", sep=",", header=None)

# %%
df2
# Out:
#          0      1      2          3      4
# 0      NaN     TV  radio  newspaper  sales
# 1      1.0  230.1   37.8       69.2   22.1
# 2      2.0   44.5   39.3       45.1   10.4
# 3      3.0   17.2   45.9       69.3    9.3
# 4      4.0  151.5   41.3       58.5   18.5
# ..     ...    ...    ...        ...    ...
# 196  196.0   38.2    3.7       13.8    7.6
# 197  197.0   94.2    4.9        8.1    9.7
# 198  198.0    177    9.3        6.4   12.8
# 199  199.0  283.6     42       66.2   25.5
# 200  200.0  232.1    8.6        8.7   13.4
#
# [201 rows x 5 columns]

# %%
df3 = pd.read_csv("./DataSets/Advertising.csv", header = None, names = ['a', 'b', 'c', 'd', 'e'])

# %%
df3
# Out:
#          a      b      c          d      e
# 0      NaN     TV  radio  newspaper  sales
# 1      1.0  230.1   37.8       69.2   22.1
# 2      2.0   44.5   39.3       45.1   10.4
# 3      3.0   17.2   45.9       69.3    9.3
# 4      4.0  151.5   41.3       58.5   18.5
# ..     ...    ...    ...        ...    ...
# 196  196.0   38.2    3.7       13.8    7.6
# 197  197.0   94.2    4.9        8.1    9.7
# 198  198.0    177    9.3        6.4   12.8
# 199  199.0  283.6     42       66.2   25.5
# 200  200.0  232.1    8.6        8.7   13.4
#
# [201 rows x 5 columns]

# %%
df4 = pd.read_csv("./DataSets/Advertising.csv", header= None, names = ['a', 'b', 'c', 'd', 'e'], skiprows=[0]) # skip rhe given row in the dataset

# %%
df4
# Out:
#        a      b     c     d     e
# 0      1  230.1  37.8  69.2  22.1
# 1      2   44.5  39.3  45.1  10.4
# 2      3   17.2  45.9  69.3   9.3
# 3      4  151.5  41.3  58.5  18.5
# 4      5  180.8  10.8  58.4  12.9
# ..   ...    ...   ...   ...   ...
# 195  196   38.2   3.7  13.8   7.6
# 196  197   94.2   4.9   8.1   9.7
# 197  198  177.0   9.3   6.4  12.8
# 198  199  283.6  42.0  66.2  25.5
# 199  200  232.1   8.6   8.7  13.4
#
# [200 rows x 5 columns]

# %%
df5 = pd.read_csv("./DataSets/Advertising.csv", header = None, names = ['a', 'b', 'c', 'd', 'e'], na_values="1") # Treats the na_values contents as NaN

# %%
df5
# Out:
#          a      b      c          d      e
# 0      NaN     TV  radio  newspaper  sales
# 1      NaN  230.1   37.8       69.2   22.1
# 2      2.0   44.5   39.3       45.1   10.4
# 3      3.0   17.2   45.9       69.3    9.3
# 4      4.0  151.5   41.3       58.5   18.5
# ..     ...    ...    ...        ...    ...
# 196  196.0   38.2    3.7       13.8    7.6
# 197  197.0   94.2    4.9        8.1    9.7
# 198  198.0    177    9.3        6.4   12.8
# 199  199.0  283.6     42       66.2   25.5
# 200  200.0  232.1    8.6        8.7   13.4
#
# [201 rows x 5 columns]

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# TV            float64
# radio         float64
# newspaper     float64
# sales         float64
# dtype: object

# %%
"""Here  count displays 200 for all the columns. So we can conclude that there doesn't exists any NA Values"""

df.describe() # Generates descriptive statistics.
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
""" Write the DataFrame content to the CSV File"""

df.to_csv("result.csv", index = False, header = False) # writing data to the csv file

# %%
""" Write only specified columns to the outp;ut file"""

df.to_csv("res.csv", index = False, columns=["TV", "radio"])

# %%
# columns is an attribute of data frame, so we are not using parenthesis while invoking.
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
df['TV']
# Out:
# 0      230.1
# 1       44.5
# 2       17.2
# 3      151.5
# 4      180.8
#        ...
# 195     38.2
# 196     94.2
# 197    177.0
# 198    283.6
# 199    232.1
# Name: TV, Length: 200, dtype: float64

# %%
type(df['TV'])
# Out:
# pandas.core.series.Series

# %%
type(df[['TV']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['TV', 'radio']]
# Out:
#         TV  radio
# 0    230.1   37.8
# 1     44.5   39.3
# 2     17.2   45.9
# 3    151.5   41.3
# 4    180.8   10.8
# ..     ...    ...
# 195   38.2    3.7
# 196   94.2    4.9
# 197  177.0    9.3
# 198  283.6   42.0
# 199  232.1    8.6
#
# [200 rows x 2 columns]

# %%
excel = pd.read_excel("./DataSets/EMC Report.xlsx", sheet_name="EMC Report Details_copied")

# %%
excel
# Out:
#      Catalog   Object Type                 Name test P-L
# 0    eMovies  Entity/Table             EMPLOYEE   COPIED
# 1    eMovies  Entity/Table                MOVIE   COPIED
# 2    eMovies  Entity/Table                STORE   COPIED
# 3    eMovies  Entity/Table  MOVIE RENTAL RECORD     Warn
# 4    eMovies  Entity/Table           MOVIE COPY     Warn
# ..       ...           ...                  ...      ...
# 160  eMovies  Relationship                is in   COPIED
# 161  eMovies  Relationship                  R/8     Warn
# 162  eMovies  Relationship                R/7_1     Warn
# 163  eMovies  Relationship                R/7_2     Warn
# 164  eMovies  Relationship                  R/6     Warn
#
# [165 rows x 4 columns]

# %%
excel.describe()
# Out:
#         Catalog       Object Type             Name test P-L
# count       165               165              165      146
# unique        1                 4              127        2
# top     eMovies  Attribute/Column  customer number     Warn
# freq        165               117                5       90

# %%
titanic_df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv") # only raw data can be accessed over URL Links.

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
s = """
{
"name" : "VENKAT",
"Phone": "7799449426",
"companies": ["wipro", "Erwin", "Quest"]
}
"""

# %%
import json

# %%
json_data = json.loads(s) # Loading the Dictionary into JSON Object

# %%
json_data
# Out:
# {'name': 'VENKAT',
#  'Phone': '7799449426',
#  'companies': ['wipro', 'Erwin', 'Quest']}

# %%
""" Conversion of JSON Data into Tabular Format"""
pd.DataFrame(json_data)
# Out:
#      name       Phone companies
# 0  VENKAT  7799449426     wipro
# 1  VENKAT  7799449426     Erwin
# 2  VENKAT  7799449426     Quest

# %%
pd.DataFrame(json_data, columns=["companies"])
# Out:
#   companies
# 0     wipro
# 1     Erwin
# 2     Quest

# %%
import requests

# %%
result = requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
result.json()
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48652',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48652/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48652/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48652/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/48652',
#   'id': 1378773381,
#   'node_id': 'I_kwDOAA0YD85SLmmF',
#   'number': 48652,
#   'title': 'BUG: the rolling.Rolling subclass cannot handle string when using apply function',
#   'user': {'login': 'shuimei',
#    'id': 16859022,
#    'node_id': 'MDQ6VXNlcjE2ODU5MDIy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16859022?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shuimei',
#    'html_url': 'https://github.com/shuimei',
#    'followers_url': 'https://api.github.com/users/shuimei/followers',
#    'following_url': 'https://api.github.com/users/shuimei/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/shuimei/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/shuimei/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/shuimei/subscriptions',
#    'organizations_url': 'https://api.github.com/users/shuimei/orgs',
#    'repos_url': 'https://api.github.com/users/shuimei/repos',
#    'events_url': 'https://api.github.com/users/shuimei/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/shuimei/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-09-20T03:43:00Z',
#   'updated_at': '2022-09-20T03:43:39Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\ndf = pd.DataFrame({"aqi_level": ["优"] * 20 + ["良"] * 20})\r\ndf.rolling(4).apply(lambda a: len(list(a)))\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nthe example code raise a DataError\r\nDataError: No numeric types to aggregate\r\n```python\r\n---------------------------------------------------------------------------\r\nDataError                                 Traceback (most recent call last)\r\nInput In [6], in <cell line: 1>()\r\n----> 1 df.rolling(4).apply(lambda a: len(a))\r\n\r\nFile /home/software/conda/lib/python3.9/site-packages/pandas/core/window/rolling.py:2000, in Rolling.apply(self, func, raw, engine, engine_kwargs, args, kwargs)\r\n   1979 @doc(\r\n   1980     template_header,\r\n   1981     create_section_header("Parameters"),\r\n   (...)\r\n   1998     kwargs: dict[str, Any] | None = None,\r\n   1999 ):\r\n-> 2000     return super().apply(\r\n   2001         func,\r\n   2002         raw=raw,\r\n   2003         engine=engine,\r\n   2004         engine_kwargs=engine_kwargs,\r\n   2005         args=args,\r\n   2006         kwargs=kwargs,\r\n   2007     )\r\n\r\nFile /home/software/conda/lib/python3.9/site-packages/pandas/core/window/rolling.py:1422, in RollingAndExpandingMixin.apply(self, func, raw, engine, engine_kwargs, args, kwargs)\r\n   1419 else:\r\n   1420     raise ValueError("engine must be either \'numba\' or \'cython\'")\r\n-> 1422 return self._apply(\r\n   1423     apply_func,\r\n   1424     name="apply",\r\n   1425     numba_args=numba_args,\r\n   1426 )\r\n\r\nFile /home/software/conda/lib/python3.9/site-packages/pandas/core/window/rolling.py:663, in BaseWindow._apply(self, func, name, numeric_only, numba_args, **kwargs)\r\n    660     return result\r\n    662 if self.method == "single":\r\n--> 663     return self._apply_blockwise(homogeneous_func, name, numeric_only)\r\n    664 else:\r\n    665     return self._apply_tablewise(homogeneous_func, name, numeric_only)\r\n\r\nFile /home/software/conda/lib/python3.9/site-packages/pandas/core/window/rolling.py:555, in BaseWindow._apply_blockwise(self, homogeneous_func, name, numeric_only)\r\n    545     dropped = obj.columns.difference(obj.columns.take(taker))\r\n    546     warnings.warn(\r\n    547         "Dropping of nuisance columns in rolling operations "\r\n    548         "is deprecated; in a future version this will raise TypeError. "\r\n   (...)\r\n    552         stacklevel=find_stack_level(inspect.currentframe()),\r\n    553     )\r\n--> 555 return self._resolve_output(df, obj)\r\n\r\nFile /home/software/conda/lib/python3.9/site-packages/pandas/core/window/rolling.py:450, in BaseWindow._resolve_output(self, out, obj)\r\n    448 """Validate and finalize result."""\r\n    449 if out.shape[1] == 0 and obj.shape[1] > 0:\r\n--> 450     raise DataError("No numeric types to aggregate")\r\n    451 elif out.shape[1] == 0:\r\n    452     return obj.astype("float64")\r\n\r\nDataError: No numeric types to aggregate\r\n```\r\n\r\n### Expected Behavior\r\n\r\njust like a single groupby apply function, output a length of every group/rolling\r\n\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 224458ee25d92ccdf289d1ae2741d178df4f323e\r\npython           : 3.9.7.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 3.10.0-327.el7.x86_64\r\nVersion          : #1 SMP Thu Nov 19 22:10:57 UTC 2015\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : zh_CN.UTF-8\r\nLOCALE           : zh_CN.UT ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48652/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48652/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48651',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48651/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48651/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48651/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48651',
#   'id': 1378708901,
#   'node_id': 'PR_kwDOAA0YD84_PRes',
#   'number': 48651,
#   'title': 'REGR: TextIOWrapper raising an error in read_csv',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-09-20T01:49:10Z',
#   'updated_at': '2022-09-20T02:08:59Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48651',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48651',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48651.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48651.patch',
#    'merged_at': None},
#   'body': '- [x] closes #48646\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nIf `TextIOWrapper.buffer` has some more unexpected surprises, it might be worth not to use this shortcut (use src instead of src.buffer). Or only have this shortcut when pandas opens the file.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48651/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48651/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48650',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48650/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48650/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48650/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/48650',
#   'id': 1378690745,
#   'node_id': 'I_kwDOAA0YD85SLSa5',
#   'number': 48650,
#   'title': 'ENH: return current class name in deprecate_nonkeyword_arguments',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-09-20T01:14:27Z',
#   'updated_at': '2022-09-20T01:14:27Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '```py\r\nclass A:\r\n    @deprecate_nonkeyword_arguments(version=None, allowed_args=["self"])\r\n    def method(self, deprecated_positional=None): ...\r\n\r\nclass B(A): ...\r\n\r\nB().method(1)  # will warn about `A.method`\r\n```\r\nMight be nice to warn about `B.method`  https://github.com/pandas-dev/pandas/pull/48592#discussion_r974747938\r\n\r\n\r\nCould probably use something like `args[0].__class__.__name__` inside the decorator but that assumes that the decorated object is a method and not a function.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48650/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48650/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48649',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48649/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48649/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48649/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/48649',
#   'id': 1378571679,
#   'node_id': 'I_kwDOAA0YD85SK1Wf',
#   'number': 48649,
#   'title': 'BUG: `df.to_excel` fails for `"border-style: hair"` with `xlsxwriter`',
#   'user': {'login': 'tehunter',
#    'id': 7980666,
#    'node_id': 'MDQ6VXNlcjc5ODA2NjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7980666?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tehunter',
#    'html_url': 'https://github.com/tehunter',
#    'followers_url': 'https://api.github.com/users/tehunter/followers',
#    'following_url': 'https://api.github.com/users/tehunter/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tehunter/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tehunter/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tehunter/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tehunter/orgs',
#    'repos_url': 'https://api.github.com/users/tehunter/repos',
#    'events_url': 'https://api.github.com/users/tehunter/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tehunter/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 49254273,
#     'node_id': 'MDU6TGFiZWw0OTI1NDI3Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20Excel',
#     'name': 'IO Excel',
#     'color': 'bfe5bf',
#     'default': False,
#     'description': 'read_excel, to_excel'},
#    {'id': 1728592794,
#     'node_id': 'MDU6TGFiZWwxNzI4NTkyNzk0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Styler',
#     'name': 'Styler',
#     'color': '006b75',
#     'default': False,
#     'description': 'conditional formatting using DataFrame.style'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'tehunter',
#    'id': 7980666,
#    'node_id': 'MDQ6VXNlcjc5ODA2NjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7980666?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tehunter',
#    'html_url': 'https://github.com/tehunter',
#    'followers_url': 'https://api.github.com/users/tehunter/followers',
#    'following_url': 'https://api.github.com/users/tehunter/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tehunter/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tehunter/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tehunter/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tehunter/orgs',
#    'repos_url': 'https://api.github.com/users/tehunter/repos',
#    'events_url': 'https://api.github.com/users/tehunter/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tehunter/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'tehunter',
#     'id': 7980666,
#     'node_id': 'MDQ6VXNlcjc5ODA2NjY=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/7980666?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/tehunter',
#     'html_url': 'https://github.com/tehunter',
#     'followers_url': 'https://api.github.com/users/tehunter/followers',
#     'following_url': 'https://api.github.com/users/tehunter/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/tehunter/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/tehunter/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/tehunter/subscriptions',
#     'organizations_url': 'https://api.github.com/users/tehunter/orgs',
#     'repos_url': 'https://api.github.com/users/tehunter/repos',
#     'events_url': 'https://api.github.com/users/tehunter/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/tehunter/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2022-09-19T22:00:40Z',
#   'updated_at': '2022-09-20T03:22:25Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\ndf = pd.DataFrame({"a": [1]})\r\nstyler = df.style.applymap(lambda x: "border-style: hair; border-color: black")\r\n\r\nstyler.to_excel(r"test_border.xlsx", engine="xlsxwriter")\n```\n\n\n### Issue Description\n\nThe `CSSToExcelConverter._border_style` function does not return any value (i.e., None) when the style string is not recognized. However, "hair" should be a recognized style string in xlsxwriter, corresponding to [border index "1"](https://xlsxwriter.readthedocs.io/format.html#set_border). This leads to a crash in `xlsxwriter`. Moreover, there is no path to actually return the "hair" style for any engine.\n\n### Expected Behavior\n\nUse of `border-style: hair` will export a spreadsheet with the correct formatting.\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 224458ee25d92ccdf289d1ae2741d178df4f323e\r\npython           : 3.10.4.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19044\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 142 Stepping 12, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_United States.1252\r\n\r\npandas           : 1.5.0rc0\r\nnumpy            : 1.21.6\r\npytz             : 2022.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 63.4.1\r\npip              : 22.1.2\r\nCython           : None\r\npytest           : 7.1.2\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : 3.0.3\r\nlxml.etree       : 4.9.1\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.2\r\nIPython          : 8.4.0\r\npandas_datareader: None\r\nbs4              : 4.11.1\r\nbottleneck       : 1.3.5\r\nbrotli           : None\r\nfastparquet      : 0.5.0\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : 0.55.2\r\nnumexpr          : 2.8.3\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npandas_gbq       : None\r\npyarrow          : 8.0.0\r\npyreadstat       : 1.1.9\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : 2.0.1\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48649/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48649/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48648',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48648/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48648/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48648/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48648',
#   'id': 1378563961,
#   'node_id': 'PR_kwDOAA0YD84_Oy-7',
#   'number': 48648,
#   'title': 'Backport PR #48639 on branch 1.5.x (CI: Fix directory name for published prod docs)',
#   'user': {'login': 'meeseeksmachine',
#    'id': 39504233,
#    'node_id': 'MDQ6VXNlcjM5NTA0MjMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39504233?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/meeseeksmachine',
#    'html_url': 'https://github.com/meeseeksmachine',
#    'followers_url': 'https://api.github.com/users/meeseeksmachine/followers',
#    'following_url': 'https://api.github.com/users/meeseeksmachine/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/meeseeksmachine/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/meeseeksmachine/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/meeseeksmachine/subscriptions',
#    'organizations_url': 'https://api.github.com/users/meeseeksmachine/orgs',
#    'repos_url': 'https://api.github.com/users/meeseeksmachine/repos',
#    'events_url': 'https://api.github.com/users/meeseeksmachine/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/meeseeksmachine/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/98',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/98',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/98/labels',
#    'id': 8438761,
#    'node_id': 'MI_kwDOAA0YD84AgMPp',
#    'number': 98,
#    'title': '1.5.1',
#    'description': 'on-merge: backport to 1.5.x',
#    'creator': {'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 15,
#    'closed_issues': 2,
#    'state': 'open',
#    'created_at': '2022-09-19T20:12:38Z',
#    'updated_at': '2022-09-19T22:55:57Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-09-19T21:52:07Z',
#   'updated_at': '2022-09-19T21:52:08Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48648',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48648',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48648.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48648.patch',
#    'merged_at': None},
#   'body': 'Backport PR #48639: CI: Fix directory name for published prod docs',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48648/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48648/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48647',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48647/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48647/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48647/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48647',
#   'id': 1378558740,
#   'node_id': 'PR_kwDOAA0YD84_Ox3y',
#   'number': 48647,
#   'title': 'Backport PR #48642 on branch 1.5.x (DOC: Add release notes for 1.5.1)',
#   'user': {'login': 'meeseeksmachine',
#    'id': 39504233,
#    'node_id': 'MDQ6VXNlcjM5NTA0MjMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39504233?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/meeseeksmachine',
#    'html_url': 'https://github.com/meeseeksmachine',
#    'followers_url': 'https://api.github.com/users/meeseeksmachine/followers',
#    'following_url': 'https://api.github.com/users/meeseeksmachine/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/meeseeksmachine/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/meeseeksmachine/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/meeseeksmachine/subscriptions',
#    'organizations_url': 'https://api.github.com/users/meeseeksmachine/orgs',
#    'repos_url': 'https://api.github.com/users/meeseeksmachine/repos',
#    'events_url': 'https://api.github.com/users/meeseeksmachine/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/meeseeksmachine/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/98',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/98',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/98/labels',
#    'id': 8438761,
#    'node_id': 'MI_kwDOAA0YD84AgMPp',
#    'number': 98,
#    'title': '1.5.1',
#    'description': 'on-merge: backport to 1.5.x',
#    'creator': {'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 15,
#    'closed_issues': 2,
#    'state': 'open',
#    'created_at': '2022-09-19T20:12:38Z',
#    'updated_at': '2022-09-19T22:55:57Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-09-19T21:45:35Z',
#   'updated_at': '2022-09-19T21:45:36Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48647',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48647',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48647.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48647.patch',
#    'merged_at': None},
#   'body': 'Backport PR #48642: DOC: Add release notes for 1.5.1',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48647/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48647/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48646',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48646/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48646/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48646/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/48646',
#   'id': 1378555272,
#   'node_id': 'I_kwDOAA0YD85SKxWI',
#   'number': 48646,
#   'title': 'BUG: regression in read_csv reading from file stream with encoding',
#   'user': {'login': 'coroa',
#    'id': 2552981,
#    'node_id': 'MDQ6VXNlcjI1NTI5ODE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2552981?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/coroa',
#    'html_url': 'https://github.com/coroa',
#    'followers_url': 'https://api.github.com/users/coroa/followers',
#    'following_url': 'https://api.github.com/users/coroa/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/coroa/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/coroa/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/coroa/subscriptions',
#    'organizations_url': 'https://api.github.com/users/coroa/orgs',
#    'repos_url': 'https://api.github.com/users/coroa/repos',
#    'events_url': 'https://api.github.com/users/coroa/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/coroa/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'},
#    {'id': 47229171,
#     'node_id': 'MDU6TGFiZWw0NzIyOTE3MQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20CSV',
#     'name': 'IO CSV',
#     'color': '5319e7',
#     'default': False,
#     'description': 'read_csv, to_csv'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/98',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/98',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/98/labels',
#    'id': 8438761,
#    'node_id': 'MI_kwDOAA0YD84AgMPp',
#    'number': 98,
#    'title': '1.5.1',
#    'description': 'on-merge: backport to 1.5.x',
#    'creator': {'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 15,
#    'closed_issues': 2,
#    'state': 'open',
#    'created_at': '2022-09-19T20:12:38Z',
#    'updated_at': '2022-09-19T22:55:57Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 3,
#   'created_at': '2022-09-19T21:41:10Z',
#   'updated_at': '2022-09-19T22:36:40Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\nimport tempfile\r\n\r\nwith tempfile.NamedTemporaryFile("wt", encoding="utf-8", delete=False) as f:\r\n    f.write("### DATA\\nkey,value\\ntables,rectangular\\n")\r\n\r\nwith open(f.name, \'r\', encoding="utf-8") as fin:\r\n    fin.readline()\r\n    pd.read_csv(fin)\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nFails in `TextReader.__cinit__` with `EmptyDataError` in pandas `1.5.0`, while it completed correctly in `1.4.4`. Using the system default encoding of `"UTF-8"` (uppercase) completes correctly as well (as does omitting the `encoding` argument in `open`).\r\n\r\n```python\r\nFile ~/.local/conda/envs/datatoolbox_test/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py:92, in CParserWrapper.__init__(self, src, **kwds)\r\n     89     kwds.pop(key, None)\r\n     91 kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))\r\n---> 92 self._reader = parsers.TextReader(src, **kwds)\r\n     94 self.unnamed_cols = self._reader.unnamed_cols\r\n     96 # error: Cannot determine type of \'names\'\r\n\r\nFile ~/.local/conda/envs/datatoolbox_test/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:554, in pandas._libs.parsers.TextReader.__cinit__()\r\n\r\nEmptyDataError: No columns to parse from file\r\n```\r\n\r\n### Expected Behavior\r\n\r\nNo raise. `pd.read_csv` reads in table.\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 87cfe4e38bafe7300a6003a1d18bd80f3f77c763\r\npython           : 3.8.13.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 21.6.0\r\nVersion          : Darwin Kernel Version 21.6.0: Sat Jun 18 17:07:25 PDT 2022; root:xnu-8020.140.41~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_GB.UTF-8\r\nLOCALE           : en_GB.UTF-8\r\n\r\npandas           : 1.5.0\r\nnumpy            : 1.23.3\r\npytz             : 2022.2.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 65.3.0\r\npip              : 22.2.2\r\nCython           : None\r\npytest           : 7.1.3\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : 3.0.3\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.2\r\nIPython          : 8.5.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : 3.6.0\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.9.1\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : 0.8.10\r\nxarray           : 2022.6.0\r\nxlrd             : 2.0.1\r\nxlwt             : 1.3.0\r\nzstandard        : None\r\ntzdata           : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48646/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48646/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48645',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48645/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48645/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48645/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/48645',
#   'id': 1378521119,
#   'node_id': 'I_kwDOAA0YD85SKpAf',
#   'number': 48645,
#   'title': 'BUG: `dropna` affects `observed` in `DataFrame.groupby()` since v1.5 ',
#   'user': {'login': 'pwwang',
#    'id': 1188067,
#    'node_id': 'MDQ6VXNlcjExODgwNjc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1188067?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pwwang',
#    'html_url': 'https://github.com/pwwang',
#    'followers_url': 'https://api.github.com/users/pwwang/followers',
#    'following_url': 'https://api.github.com/users/pwwang/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/pwwang/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/pwwang/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/pwwang/subscriptions',
#    'organizations_url': 'https://api.github.com/users/pwwang/orgs',
#    'repos_url': 'https://api.github.com/users/pwwang/repos',
#    'events_url': 'https://api.github.com/users/pwwang/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/pwwang/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'rhshadrach',
#     'id': 45562402,
#     'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/rhshadrach',
#     'html_url': 'https://github.com/rhshadrach',
#     'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#     'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#     'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#     'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#     'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/98',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/98',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/98/labels',
#    'id': 8438761,
#    'node_id': 'MI_kwDOAA0YD84AgMPp',
#    'number': 98,
#    'title': '1.5.1',
#    'description': 'on-merge: backport to 1.5.x',
#    'creator': {'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 15,
#    'closed_issues': 2,
#    'state': 'open',
#    'created_at': '2022-09-19T20:12:38Z',
#    'updated_at': '2022-09-19T22:55:57Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2022-09-19T21:06:02Z',
#   'updated_at': '2022-09-19T22:47:01Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
# ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48609/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48609/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48608',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48608/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48608/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48608/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48608',
#   'id': 1376826528,
#   'node_id': 'PR_kwDOAA0YD84_JKgi',
#   'number': 48608,
#   'title': 'REGR: assert_index_equal raising with non matching pd.NA',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 1817503692,
#     'node_id': 'MDU6TGFiZWwxODE3NTAzNjky',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/NA%20-%20MaskedArrays',
#     'name': 'NA - MaskedArrays',
#     'color': '8cc645',
#     'default': False,
#     'description': 'Related to pd.NA and nullable extension arrays'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/98',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/98',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/98/labels',
#    'id': 8438761,
#    'node_id': 'MI_kwDOAA0YD84AgMPp',
#    'number': 98,
#    'title': '1.5.1',
#    'description': 'on-merge: backport to 1.5.x',
#    'creator': {'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 15,
#    'closed_issues': 2,
#    'state': 'open',
#    'created_at': '2022-09-19T20:12:38Z',
#    'updated_at': '2022-09-19T22:55:57Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-09-17T17:16:03Z',
#   'updated_at': '2022-09-19T21:49:28Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48608',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48608',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48608.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48608.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nI'd like to backport this (not necessarily to 1.5.0, 1.5.1 would be fine too). EAs in Index objects are new in 1.4, so this can be considered a regression.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48608/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48608/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48606',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48606/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48606/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48606/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48606',
#   'id': 1376785563,
#   'node_id': 'PR_kwDOAA0YD84_JDGc',
#   'number': 48606,
#   'title': 'BUG: MultiIndex.difference not keeping ea dtype',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 71268330,
#     'node_id': 'MDU6TGFiZWw3MTI2ODMzMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/MultiIndex',
#     'name': 'MultiIndex',
#     'color': '207de5',
#     'default': False,
#     'description': None},
#    {'id': 1817503692,
#     'node_id': 'MDU6TGFiZWwxODE3NTAzNjky',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/NA%20-%20MaskedArrays',
#     'name': 'NA - MaskedArrays',
#     'color': '8cc645',
#     'default': False,
#     'description': 'Related to pd.NA and nullable extension arrays'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-09-17T14:19:17Z',
#   'updated_at': '2022-09-19T21:49:28Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48606',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48606',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48606.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48606.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\n\r\n```\r\n       before           after         ratio\r\n     [b5632fb3]       [c8b6d846]\r\n     <deprecation_notes~1>       <diff>    \r\n-     5.67±0.08ms       4.73±0.1ms     0.83  multiindex_object.Difference.time_difference('string')\r\n-     4.65±0.01ms      3.71±0.03ms     0.80  multiindex_object.Difference.time_difference('int')\r\n-     4.78±0.02ms      3.75±0.01ms     0.78  multiindex_object.Difference.time_difference('ea_int')\r\n-     6.35±0.02ms      4.85±0.02ms     0.76  multiindex_object.Difference.time_difference('datetime')\r\n```",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48606/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48606/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48603',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48603/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48603/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48603/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48603',
#   'id': 1376765872,
#   'node_id': 'PR_kwDOAA0YD84_I_fx',
#   'number': 48603,
#   'title': 'PERF: Avoid fragmentation of DataFrame in read_sas',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 258745163,
#     'node_id': 'MDU6TGFiZWwyNTg3NDUxNjM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20SAS',
#     'name': 'IO SAS',
#     'color': '5319e7',
#     'default': False,
#     'description': 'SAS: read_sas'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/97',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/97',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/97/labels',
#    'id': 8341565,
#    'node_id': 'MI_kwDOAA0YD84Af0g9',
#    'number': 97,
#    'title': '1.6',
#    'description': '',
#    'creator': {'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 9,
#    'closed_issues': 109,
#    'state': 'open',
#    'created_at': '2022-08-23T17:53:13Z',
#    'updated_at': '2022-09-19T23:21:57Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2022-09-17T12:57:08Z',
#   'updated_at': '2022-09-19T23:02:35Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/48603',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/48603',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/48603.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/48603.patch',
#    'merged_at': None},
#   'body': '- [x] closes #48595 (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nNot sure how to test this, the op file is 13mb which is way to large for our repository.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48603/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48603/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
json_pd = result.json()

# %%
for i in range(len(json_pd)):
    print(json_pd[i]['title'])
# Out:
# BUG: the rolling.Rolling subclass cannot handle string when using apply function
# REGR: TextIOWrapper raising an error in read_csv
# ENH: return current class name in deprecate_nonkeyword_arguments
# BUG: `df.to_excel` fails for `"border-style: hair"` with `xlsxwriter`
# Backport PR #48639 on branch 1.5.x (CI: Fix directory name for published prod docs)
# Backport PR #48642 on branch 1.5.x (DOC: Add release notes for 1.5.1)
# BUG: regression in read_csv reading from file stream with encoding
# BUG: `dropna` affects `observed` in `DataFrame.groupby()` since v1.5
# DOC: Sticky Headers in Table Visualization is broken in v1.5.0
# aarch64 wheel missing on pip for 1.5.0
# BUG: StringArray is a subclass of PandasArray
# BUG: Fixed DataFrame.__repr__ Type Error when column dtype is np.record (GH 48526)
# DOC: `value_counts` description doesn't match code logic
# BUG: guessing datetime format fails with 200622-12-31
# DOC: GL08 errors in pandas.Timestamp
# DOC: Update documentation for date_range(), bdate_range(), and interval_range() to include timedelta as a possible data type for the freq parameter
# REGR: sort_value can not sort levels with non nas and nans
# PDEP-4: consistent parsing of datetimes
# REGR: Performance decrease in factorize
# TST: add test case for PeriodIndex in HDFStore(GH7796)
# BUG: Fix metadata propagation in df.corr and df.cov, GH28283
# WIP: Multichar comment
# Revised the doc-string for _app_template to bring in line with curren…
# TYP: tighten Axis
# PERF: join/merge on subset of MultiIndex
# BUG: pandas.to_datetime fails to handle numpy.nan on riscv64 due to dependency on undefined behaviour
# PERF: DatetimeIndex constructor from list
# REGR: assert_index_equal raising with non matching pd.NA
# BUG: MultiIndex.difference not keeping ea dtype
# PERF: Avoid fragmentation of DataFrame in read_sas

# %%
"""
result = requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")
json_pd = result.json()
"""
pd.DataFrame(json_pd, columns = ['url', 'title'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                 title
# 0   BUG: the rolling.Rolling subclass cannot handl...
# 1    REGR: TextIOWrapper raising an error in read_csv
# 2   ENH: return current class name in deprecate_no...
# 3   BUG: `df.to_excel` fails for `"border-style: h...
# 4   Backport PR #48639 on branch 1.5.x (CI: Fix di...
# 5   Backport PR #48642 on branch 1.5.x (DOC: Add r...
# 6   BUG: regression in read_csv reading from file ...
# 7   BUG: `dropna` affects `observed` in `DataFrame...
# 8   DOC: Sticky Headers in Table Visualization is ...
# 9              aarch64 wheel missing on pip for 1.5.0
# 10      BUG: StringArray is a subclass of PandasArray
# 11  BUG: Fixed DataFrame.__repr__ Type Error when ...
# 12  DOC: `value_counts` description doesn't match ...
# 13  BUG: guessing datetime format fails with 20062...
# 14               DOC: GL08 errors in pandas.Timestamp
# 15  DOC: Update documentation for date_range(), bd...
# 16  REGR: sort_value can not sort levels with non ...
# 17            PDEP-4: consistent parsing of datetimes
# 18            REGR: Performance decrease in factorize
# 19  TST: add test case for PeriodIndex in HDFStore...
# 20  BUG: Fix metadata propagation in df.corr and d...
# 21                             WIP: Multichar comment
# 22  Revised the doc-string for _app_template to br...
# 23                                  TYP: tighten Axis
# 24           PERF: join/merge on subset of MultiIndex
# 25  BUG: pandas.to_datetime fails to handle numpy....
# 26          PERF: DatetimeIndex constructor from list
# 27  REGR: assert_index_equal raising with non matc...
# 28    BUG: MultiIndex.difference not keeping ea dtype
# 29  PERF: Avoid fragmentation of DataFrame in read...

# %%
json_pd[0]['labels']
# Out:
# [{'id': 76811,
#   'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#   'name': 'Bug',
#   'color': 'e10c02',
#   'default': False,
#   'description': None},
#  {'id': 1954720290,
#   'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#   'name': 'Needs Triage',
#   'color': '0052cc',
#   'default': False,
#   'description': 'Issue that has not been reviewed by a pandas team member'}]

# %%
pd.DataFrame(json_pd[0]['labels'])
# Out:
#            id                   node_id  \
# 0       76811      MDU6TGFiZWw3NjgxMQ==
# 1  1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
#
#                                                  url          name   color  \
# 0  https://api.github.com/repos/pandas-dev/pandas...           Bug  e10c02
# 1  https://api.github.com/repos/pandas-dev/pandas...  Needs Triage  0052cc
#
#    default                                        description
# 0    False                                               None
# 1    False  Issue that has not been reviewed by a pandas t...

# %%
user_list = []
for i in range(len(json_pd)):
               user_list.append(json_pd[i]['user'])

# %%
pd.DataFrame(user_list)
# Out:
#               login        id               node_id  \
# 0           shuimei  16859022  MDQ6VXNlcjE2ODU5MDIy
# 1        twoertwein   6618166  MDQ6VXNlcjY2MTgxNjY=
# 2        twoertwein   6618166  MDQ6VXNlcjY2MTgxNjY=
# 3          tehunter   7980666  MDQ6VXNlcjc5ODA2NjY=
# 4   meeseeksmachine  39504233  MDQ6VXNlcjM5NTA0MjMz
# 5   meeseeksmachine  39504233  MDQ6VXNlcjM5NTA0MjMz
# 6             coroa   2552981  MDQ6VXNlcjI1NTI5ODE=
# 7            pwwang   1188067  MDQ6VXNlcjExODgwNjc=
# 8          tehunter   7980666  MDQ6VXNlcjc5ODA2NjY=
# 9         xconverge   4219348  MDQ6VXNlcjQyMTkzNDg=
# 10          ehsantn   2333645  MDQ6VXNlcjIzMzM2NDU=
# 11          RaphSku  45042665  MDQ6VXNlcjQ1MDQyNjY1
# 12    maciejskorski  31315784  MDQ6VXNlcjMxMzE1Nzg0
# 13     MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 14          Sherry3  28356592  MDQ6VXNlcjI4MzU2NTky
# 15         gandhis1  21064086  MDQ6VXNlcjIxMDY0MDg2
# 16            phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 17     MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 18       rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy
# 19      paradox-lab  57354735  MDQ6VXNlcjU3MzU0NzM1
# 20         yuanx749  47032563  MDQ6VXNlcjQ3MDMyNTYz
# 21           loodvn  13983198  MDQ6VXNlcjEzOTgzMTk4
# 22           DRudel   5006589  MDQ6VXNlcjUwMDY1ODk=
# 23       twoertwein   6618166  MDQ6VXNlcjY2MTgxNjY=
# 24       lukemanley   8519523  MDQ6VXNlcjg1MTk1MjM=
# 25   andreas-schwab   2175493  MDQ6VXNlcjIxNzU0OTM=
# 26       lukemanley   8519523  MDQ6VXNlcjg1MTk1MjM=
# 27            phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 28            phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 29            phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
#
#                                            avatar_url gravatar_id  \
# 0   https://avatars.githubusercontent.com/u/168590...
# 1   https://avatars.githubusercontent.com/u/661816...
# 2   https://avatars.githubusercontent.com/u/661816...
# 3   https://avatars.githubusercontent.com/u/798066...
# 4   https://avatars.githubusercontent.com/u/395042...
# 5   https://avatars.githubusercontent.com/u/395042...
# 6   https://avatars.githubusercontent.com/u/255298...
# 7   https://avatars.githubusercontent.com/u/118806...
# 8   https://avatars.githubusercontent.com/u/798066...
# 9   https://avatars.githubusercontent.com/u/421934...
# 10  https://avatars.githubusercontent.com/u/233364...
# 11  https://avatars.githubusercontent.com/u/450426...
# 12  https://avatars.githubusercontent.com/u/313157...
# 13  https://avatars.githubusercontent.com/u/334916...
# 14  https://avatars.githubusercontent.com/u/283565...
# 15  https://avatars.githubusercontent.com/u/210640...
# 16  https://avatars.githubusercontent.com/u/619347...
# 17  https://avatars.githubusercontent.com/u/334916...
# 18  https://avatars.githubusercontent.com/u/455624...
# 19  https://avatars.githubusercontent.com/u/573547...
# 20  https://avatars.githubusercontent.com/u/470325...
# 21  https://avatars.githubusercontent.com/u/139831...
# 22  https://avatars.githubusercontent.com/u/500658...
# 23  https://avatars.githubusercontent.com/u/661816...
# 24  https://avatars.githubusercontent.com/u/851952...
# 25  https://avatars.githubusercontent.com/u/217549...
# 26  https://avatars.githubusercontent.com/u/851952...
# 27  https://avatars.githubusercontent.com/u/619347...
# 28  https://avatars.githubusercontent.com/u/619347...
# 29  https://avatars.githubusercontent.com/u/619347...
#
#                                              url  \
# 0           https://api.github.com/users/shuimei
# 1        https://api.github.com/users/twoertwein
# 2        https://api.github.com/users/twoertwein
# 3          https://api.github.com/users/tehunter
# 4   https://api.github.com/users/meeseeksmachine
# 5   https://api.github.com/users/meeseeksmachine
# 6             https://api.github.com/users/coroa
# 7            https://api.github.com/users/pwwang
# 8          https://api.github.com/users/tehunter
# 9         https://api.github.com/users/xconverge
# 10          https://api.github.com/users/ehsantn
# 11          https://api.github.com/users/RaphSku
# 12    https://api.github.com/users/maciejskorski
# 13     https://api.github.com/users/MarcoGorelli
# 14          https://api.github.com/users/Sherry3
# 15         https://api.github.com/users/gandhis1
# 16            https://api.github.com/users/phofl
# 17     https://api.github.com/users/MarcoGorelli
# 18       https://api.github.com/users/rhshadrach
# 19      https://api.github.com/users/paradox-lab
# 20         https://api.github.com/users/yuanx749
# 21           https://api.github.com/users/loodvn
# 22           https://api.github.com/users/DRudel
# 23       https://api.github.com/users/twoertwein
# 24       https://api.github.com/users/lukemanley
# 25   https://api.github.com/users/andreas-schwab
# 26       https://api.github.com/users/lukemanley
# 27            https://api.github.com/users/phofl
# 28            https://api.github.com/users/phofl
# 29            https://api.github.com/users/phofl
#
#                               html_url  \
# 0           https://github.com/shuimei
# 1        https://github.com/twoertwein
# 2        https://github.com/twoertwein
# 3          https://github.com/tehunter
# 4   https://github.com/meeseeksmachine
# 5   https://github.com/meeseeksmachine
# 6             https://github.com/coroa
# 7            https://github.com/pwwang
# 8          https://github.com/tehunter
# 9         https://github.com/xconverge
# 10          https://github.com/ehsantn
# 11          https://github.com/RaphSku
# 12    https://github.com/maciejskorski
# 13     https://github.com/MarcoGorelli
# 14          https://github.com/Sherry3
# 15         https://github.com/gandhis1
# 16            https://github.com/phofl
# 17     https://github.com/MarcoGorelli
# 18       https://github.com/rhshadrach
# 19      https://github.com/paradox-lab
# 20         https://github.com/yuanx749
# 21           https://github.com/loodvn
# 22           https://github.com/DRudel
# 23       https://github.com/twoertwein
# 24       https://github.com/lukemanley
# 25   https://github.com/andreas-schwab
# 26       https://github.com/lukemanley
# 27            https://github.com/phofl
# 28            https://github.com/phofl
# 29            https://github.com/phofl
#
#                                         followers_url  \
# 0      https://api.github.com/users/shuimei/followers
# 1   https://api.github.com/users/twoertwein/followers
# 2   https://api.github.com/users/twoertwein/followers
# 3     https://api.github.com/users/tehunter/followers
# 4   https://api.github.com/users/meeseeksmachine/f...
# 5   https://api.github.com/users/meeseeksmachine/f...
# 6        https://api.github.com/users/coroa/followers
# 7       https://api.github.com/users/pwwang/followers
# 8     https://api.github.com/users/tehunter/followers
# 9    https://api.github.com/users/xconverge/followers
# 10     https://api.github.com/users/ehsantn/followers
# 11     https://api.github.com/users/RaphSku/followers
# 12  https://api.github.com/users/maciejskorski/fol...
# 13  https://api.github.com/users/MarcoGorelli/foll...
# 14     https://api.github.com/users/Sherry3/followers
# 15    https://api.github.com/users/gandhis1/followers
# 16       https://api.github.com/users/phofl/followers
# 17  https://api.github.com/users/MarcoGorelli/foll...
# 18  https://api.github.com/users/rhshadrach/followers
# 19  https://api.github.com/users/paradox-lab/follo...
# 20    https://api.github.com/users/yuanx749/followers
# 21      https://api.github.com/users/loodvn/followers
# 22      https://api.github.com/users/DRudel/followers
# 23  https://api.github.com/users/twoertwein/followers
# 24  https://api.github.com/users/lukemanley/followers
# 25  https://api.github.com/users/andreas-schwab/fo...
# 26  https://api.github.com/users/lukemanley/followers
# 27       https://api.github.com/users/phofl/followers
# 28       https://api.github.com/users/phofl/followers
# 29       https://api.github.com/users/phofl/followers
#
#                                         following_url  \
# 0   https://api.github.com/users/shuimei/following...
# 1   https://api.github.com/users/twoertwein/follow...
# 2   https://api.github.com/users/twoertwein/follow...
# 3   https://api.github.com/users/tehunter/followin...
# 4   https://api.github.com/users/meeseeksmachine/f...
# 5   https://api.github.com/users/meeseeksmachine/f...
# 6   https://api.github.com/users/coroa/following{/...
# 7   https://api.github.com/users/pwwang/following{...
# 8   https://api.github.com/users/tehunter/followin...
# 9   https://api.github.com/users/xconverge/followi...
# 10  https://api.github.com/users/ehsantn/following...
# 11  https://api.github.com/users/RaphSku/following...
# 12  https://api.github.com/users/maciejskorski/fol...
# 13  https://api.github.com/users/MarcoGorelli/foll...
# 14  https://api.github.com/users/Sherry3/following...
# 15  https://api.github.com/users/gandhis1/followin...
# 16  https://api.github.com/users/phofl/following{/...
# 17  https://api.github.com/users/MarcoGorelli/foll...
# 18  https://api.github.com/users/rhshadrach/follow...
# 19  https://api.github.com/users/paradox-lab/follo...
# 20  https://api.github.com/users/yuanx749/followin...
# 21  https://api.github.com/users/loodvn/following{...
# 22  https://api.github.com/users/DRudel/following{...
# 23  https://api.github.com/users/twoertwein/follow...
# 24  https://api.github.com/users/lukemanley/follow...
# 25  https://api.github.com/users/andreas-schwab/fo...
# 26  https://api.github.com/users/lukemanley/follow...
# 27  https://api.github.com/users/phofl/following{/...
# 28  https://api.github.com/users/phofl/following{/...
# 29  https://api.github.com/users/phofl/following{/...
#
#                                             gists_url  \
# 0   https://api.github.com/users/shuimei/gists{/gi...
# 1   https://api.github.com/users/twoertwein/gists{...
# 2   https://api.github.com/users/twoertwein/gists{...
# 3   https://api.github.com/users/tehunter/gists{/g...
# 4   https://api.github.com/users/meeseeksmachine/g...
# 5   https://api.github.com/users/meeseeksmachine/g...
# 6   https://api.github.com/users/coroa/gists{/gist...
# 7   https://api.github.com/users/pwwang/gists{/gis...
# 8   https://api.github.com/users/tehunter/gists{/g...
# 9   https://api.github.com/users/xconverge/gists{/...
# 10  https://api.github.com/users/ehsantn/gists{/gi...
# 11  https://api.github.com/users/RaphSku/gists{/gi...
# 12  https://api.github.com/users/maciejskorski/gis...
# 13  https://api.github.com/users/MarcoGorelli/gist...
# 14  https://api.github.com/users/Sherry3/gists{/gi...
# 15  https://api.github.com/users/gandhis1/gists{/g...
# 16  https://api.github.com/users/phofl/gists{/gist...
# 17  https://api.github.com/users/MarcoGorelli/gist...
# 18  https://api.github.com/users/rhshadrach/gists{...
# 19  https://api.github.com/users/paradox-lab/gists...
# 20  https://api.github.com/users/yuanx749/gists{/g...
# 21  https://api.github.com/users/loodvn/gists{/gis...
# 22  https://api.github.com/users/DRudel/gists{/gis...
# 23  https://api.github.com/users/twoertwein/gists{...
# 24  https://api.github.com/users/lukemanley/gists{...
# 25  https://api.github.com/users/andreas-schwab/gi...
# 26  https://api.github.com/users/lukemanley/gists{...
# 27  https://api.github.com/users/phofl/gists{/gist...
# 28  https://api.github.com/users/phofl/gists{/gist...
# 29  https://api.github.com/users/phofl/gists{/gist...
#
#                                           starred_url  \
# 0   https://api.github.com/users/shuimei/starred{/...
# 1   https://api.github.com/users/twoertwein/starre...
# 2   https://api.github.com/users/twoertwein/starre...
# 3   https://api.github.com/users/tehunter/starred{...
# 4   https://api.github.com/users/meeseeksmachine/s...
# 5   https://api.github.com/users/meeseeksmachine/s...
# 6   https://api.github.com/users/coroa/starred{/ow...
# 7   https://api.github.com/users/pwwang/starred{/o...
# 8   https://api.github.com/users/tehunter/starred{...
# 9   https://api.github.com/users/xconverge/starred...
# 10  https://api.github.com/users/ehsantn/starred{/...
# 11  https://api.github.com/users/RaphSku/starred{/...
# 12  https://api.github.com/users/maciejskorski/sta...
# 13  https://api.github.com/users/MarcoGorelli/star...
# 14  https://api.github.com/users/Sherry3/starred{/...
# 15  https://api.github.com/users/gandhis1/starred{...
# 16  https://api.github.com/users/phofl/starred{/ow...
# 17  https://api.github.com/users/MarcoGorelli/star...
# 18  https://api.github.com/users/rhshadrach/starre...
# 19  https://api.github.com/users/paradox-lab/starr...
# 20  https://api.github.com/users/yuanx749/starred{...
# 21  https://api.github.com/users/loodvn/starred{/o...
# 22  https://api.github.com/users/DRudel/starred{/o...
# 23  https://api.github.com/users/twoertwein/starre...
# 24  https://api.github.com/users/lukemanley/starre...
# 25  https://api.github.com/users/andreas-schwab/st...
# 26  https://api.github.com/users/lukemanley/starre...
# 27  https://api.github.com/users/phofl/starred{/ow...
# 28  https://api.github.com/users/phofl/starred{/ow...
# 29  https://api.github.com/users/phofl/starred{/ow...
#
#                                     subscriptions_url  \
# 0   https://api.github.com/users/shuimei/subscript...
# 1   https://api.github.com/users/twoertwein/subscr...
# 2   https://api.github.com/users/twoertwein/subscr...
# 3   https://api.github.com/users/tehunter/subscrip...
# 4   https://api.github.com/users/meeseeksmachine/s...
# 5   https://api.github.com/users/meeseeksmachine/s...
# 6    https://api.github.com/users/coroa/subscriptions
# 7   https://api.github.com/users/pwwang/subscriptions
# 8   https://api.github.com/users/tehunter/subscrip...
# 9   https://api.github.com/users/xconverge/subscri...
# 10  https://api.github.com/users/ehsantn/subscript...
# 11  https://api.github.com/users/RaphSku/subscript...
# 12  https://api.github.com/users/maciejskorski/sub...
# 13  https://api.github.com/users/MarcoGorelli/subs...
# 14  https://api.github.com/users/Sherry3/subscript...
# 15  https://api.github.com/users/gandhis1/subscrip...
# 16   https://api.github.com/users/phofl/subscriptions
# 17  https://api.github.com/users/MarcoGorelli/subs...
# 18  https://api.github.com/users/rhshadrach/subscr...
# 19  https://api.github.com/users/paradox-lab/subsc...
# 20  https://api.github.com/users/yuanx749/subscrip...
# 21  https://api.github.com/users/loodvn/subscriptions
# 22  https://api.github.com/users/DRudel/subscriptions
# 23  https://api.github.com/users/twoertwein/subscr...
# 24  https://api.github.com/users/lukemanley/subscr...
# 25  https://api.github.com/users/andreas-schwab/su...
# 26  https://api.github.com/users/lukemanley/subscr...
# 27   https://api.github.com/users/phofl/subscriptions
# 28   https://api.github.com/users/phofl/subscriptions
# 29   https://api.github.com/users/phofl/subscriptions
#
#                                     organizations_url  \
# 0           https://api.github.com/users/shuimei/orgs
# 1        https://api.github.com/users/twoertwein/orgs
# 2        https://api.github.com/users/twoertwein/orgs
# 3          https://api.github.com/users/tehunter/orgs
# 4   https://api.github.com/users/meeseeksmachine/orgs
# 5   https://api.github.com/users/meeseeksmachine/orgs
# 6             https://api.github.com/users/coroa/orgs
# 7            https://api.github.com/users/pwwang/orgs
# 8          https://api.github.com/users/tehunter/orgs
# 9         https://api.github.com/users/xconverge/orgs
# 10          https://api.github.com/users/ehsantn/orgs
# 11          https://api.github.com/users/RaphSku/orgs
# 12    https://api.github.com/users/maciejskorski/orgs
# 13     https://api.github.com/users/MarcoGorelli/orgs
# 14          https://api.github.com/users/Sherry3/orgs
# 15         https://api.github.com/users/gandhis1/orgs
# 16            https://api.github.com/users/phofl/orgs
# 17     https://api.github.com/users/MarcoGorelli/orgs
# 18       https://api.github.com/users/rhshadrach/orgs
# 19      https://api.github.com/users/paradox-lab/orgs
# 20         https://api.github.com/users/yuanx749/orgs
# 21           https://api.github.com/users/loodvn/orgs
# 22           https://api.github.com/users/DRudel/orgs
# 23       https://api.github.com/users/twoertwein/orgs
# 24       https://api.github.com/users/lukemanley/orgs
# 25   https://api.github.com/users/andreas-schwab/orgs
# 26       https://api.github.com/users/lukemanley/orgs
# 27            https://api.github.com/users/phofl/orgs
# 28            https://api.github.com/users/phofl/orgs
# 29            https://api.github.com/users/phofl/orgs
#
#                                             repos_url  \
# 0          https://api.github.com/users/shuimei/repos
# 1       https://api.github.com/users/twoertwein/repos
# 2       https://api.github.com/users/twoertwein/repos
# 3         https://api.github.com/users/tehunter/repos
# 4   https://api.github.com/users/meeseeksmachine/r...
# 5   https://api.github.com/users/meeseeksmachine/r...
# 6            https://api.github.com/users/coroa/repos
# 7           https://api.github.com/users/pwwang/repos
# 8         https://api.github.com/users/tehunter/repos
# 9        https://api.github.com/users/xconverge/repos
# 10         https://api.github.com/users/ehsantn/repos
# 11         https://api.github.com/users/RaphSku/repos
# 12   https://api.github.com/users/maciejskorski/repos
# 13    https://api.github.com/users/MarcoGorelli/repos
# 14         https://api.github.com/users/Sherry3/repos
# 15        https://api.github.com/users/gandhis1/repos
# 16           https://api.github.com/users/phofl/repos
# 17    https://api.github.com/users/MarcoGorelli/repos
# 18      https://api.github.com/users/rhshadrach/repos
# 19     https://api.github.com/users/paradox-lab/repos
# 20        https://api.github.com/users/yuanx749/repos
# 21          https://api.github.com/users/loodvn/repos
# 22          https://api.github.com/users/DRudel/repos
# 23      https://api.github.com/users/twoertwein/repos
# 24      https://api.github.com/users/lukemanley/repos
# 25  https://api.github.com/users/andreas-schwab/repos
# 26      https://api.github.com/users/lukemanley/repos
# 27           https://api.github.com/users/phofl/repos
# 28           https://api.github.com/users/phofl/repos
# 29           https://api.github.com/users/phofl/repos
#
#                                            events_url  \
# 0   https://api.github.com/users/shuimei/events{/p...
# 1   https://api.github.com/users/twoertwein/events...
# 2   https://api.github.com/users/twoertwein/events...
# 3   https://api.github.com/users/tehunter/events{/...
# 4   https://api.github.com/users/meeseeksmachine/e...
# 5   https://api.github.com/users/meeseeksmachine/e...
# 6   https://api.github.com/users/coroa/events{/pri...
# 7   https://api.github.com/users/pwwang/events{/pr...
# 8   https://api.github.com/users/tehunter/events{/...
# 9   https://api.github.com/users/xconverge/events{...
# 10  https://api.github.com/users/ehsantn/events{/p...
# 11  https://api.github.com/users/RaphSku/events{/p...
# 12  https://api.github.com/users/maciejskorski/eve...
# 13  https://api.github.com/users/MarcoGorelli/even...
# 14  https://api.github.com/users/Sherry3/events{/p...
# 15  https://api.github.com/users/gandhis1/events{/...
# 16  https://api.github.com/users/phofl/events{/pri...
# 17  https://api.github.com/users/MarcoGorelli/even...
# 18  https://api.github.com/users/rhshadrach/events...
# 19  https://api.github.com/users/paradox-lab/event...
# 20  https://api.github.com/users/yuanx749/events{/...
# 21  https://api.github.com/users/loodvn/events{/pr...
# 22  https://api.github.com/users/DRudel/events{/pr...
# 23  https://api.github.com/users/twoertwein/events...
# 24  https://api.github.com/users/lukemanley/events...
# 25  https://api.github.com/users/andreas-schwab/ev...
# 26  https://api.github.com/users/lukemanley/events...
# 27  https://api.github.com/users/phofl/events{/pri...
# 28  https://api.github.com/users/phofl/events{/pri...
# 29  https://api.github.com/users/phofl/events{/pri...
#
#                                   received_events_url  type  site_admin
# 0   https://api.github.com/users/shuimei/received_...  User       False
# 1   https://api.github.com/users/twoertwein/receiv...  User       False
# 2   https://api.github.com/users/twoertwein/receiv...  User       False
# 3   https://api.github.com/users/tehunter/received...  User       False
# 4   https://api.github.com/users/meeseeksmachine/r...  User       False
# 5   https://api.github.com/users/meeseeksmachine/r...  User       False
# 6   https://api.github.com/users/coroa/received_ev...  User       False
# 7   https://api.github.com/users/pwwang/received_e...  User       False
# 8   https://api.github.com/users/tehunter/received...  User       False
# 9   https://api.github.com/users/xconverge/receive...  User       False
# 10  https://api.github.com/users/ehsantn/received_...  User       False
# 11  https://api.github.com/users/RaphSku/received_...  User       False
# 12  https://api.github.com/users/maciejskorski/rec...  User       False
# 13  https://api.github.com/users/MarcoGorelli/rece...  User       False
# 14  https://api.github.com/users/Sherry3/received_...  User       False
# 15  https://api.github.com/users/gandhis1/received...  User       False
# 16  https://api.github.com/users/phofl/received_ev...  User       False
# 17  https://api.github.com/users/MarcoGorelli/rece...  User       False
# 18  https://api.github.com/users/rhshadrach/receiv...  User       False
# 19  https://api.github.com/users/paradox-lab/recei...  User       False
# 20  https://api.github.com/users/yuanx749/received...  User       False
# 21  https://api.github.com/users/loodvn/received_e...  User       False
# 22  https://api.github.com/users/DRudel/received_e...  User       False
# 23  https://api.github.com/users/twoertwein/receiv...  User       False
# 24  https://api.github.com/users/lukemanley/receiv...  User       False
# 25  https://api.github.com/users/andreas-schwab/re...  User       False
# 26  https://api.github.com/users/lukemanley/receiv...  User       False
# 27  https://api.github.com/users/phofl/received_ev...  User       False
# 28  https://api.github.com/users/phofl/received_ev...  User       False
# 29  https://api.github.com/users/phofl/received_ev...  User       False

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")['user']
# Out:
# 0     {'login': 'shuimei', 'id': 16859022, 'node_id'...
# 1     {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 2     {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 3     {'login': 'tehunter', 'id': 7980666, 'node_id'...
# 4     {'login': 'meeseeksmachine', 'id': 39504233, '...
# 5     {'login': 'meeseeksmachine', 'id': 39504233, '...
# 6     {'login': 'coroa', 'id': 2552981, 'node_id': '...
# 7     {'login': 'pwwang', 'id': 1188067, 'node_id': ...
# 8     {'login': 'tehunter', 'id': 7980666, 'node_id'...
# 9     {'login': 'xconverge', 'id': 4219348, 'node_id...
# 10    {'login': 'ehsantn', 'id': 2333645, 'node_id':...
# 11    {'login': 'RaphSku', 'id': 45042665, 'node_id'...
# 12    {'login': 'maciejskorski', 'id': 31315784, 'no...
# 13    {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 14    {'login': 'Sherry3', 'id': 28356592, 'node_id'...
# 15    {'login': 'gandhis1', 'id': 21064086, 'node_id...
# 16    {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 17    {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 18    {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 19    {'login': 'paradox-lab', 'id': 57354735, 'node...
# 20    {'login': 'yuanx749', 'id': 47032563, 'node_id...
# 21    {'login': 'loodvn', 'id': 13983198, 'node_id':...
# 22    {'login': 'DRudel', 'id': 5006589, 'node_id': ...
# 23    {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 24    {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 25    {'login': 'andreas-schwab', 'id': 2175493, 'no...
# 26    {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 27    {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 28    {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 29    {'login': 'phofl', 'id': 61934744, 'node_id': ...
# Name: user, dtype: object
